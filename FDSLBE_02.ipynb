# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkatasaisuggana/FDSLABEXP1/blob/main/FDSLBE_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("Titanic-Dataset.csv")
print("First Five Records")
print(df.head())
# Out:
# First Five Records
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print("\nData Types")
print(df.dtypes)
# Out:
# Data Types
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print("\nDataset Shape:", df.shape)
# Out:
# Dataset Shape: (891, 12)

# %%
print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df['Cabin'] = df['Cabin'].fillna('Unknown')

# %%
print("\nMissing Values After Imputation")
print(df.isnull().sum())
# Out:
# Missing Values After Imputation
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
print("\nDuplicate Records:", df.duplicated().sum())

df = df.drop_duplicates()

print("Dataset Shape After Removing Duplicates:", df.shape)
# Out:
# Duplicate Records: 0
# Dataset Shape After Removing Duplicates: (891, 12)

# %%
encoder = LabelEncoder()
df['Sex'] = encoder.fit_transform(df['Sex'])
df['Embarked'] = encoder.fit_transform(df['Embarked'])
print("\nEncoded Data")
print(df[['Sex','Embarked']].head())
# Out:
# Encoded Data
#    Sex  Embarked
# 0    1         2
# 1    0         0
# 2    0         2
# 3    0         2
# 4    1         2

# %%
scaler = StandardScaler()

df[['Age','Fare']] = scaler.fit_transform(df[['Age','Fare']])
print("\nStandardized Age and Fare")
print(df[['Age','Fare']].head())
# Out:
# Standardized Age and Fare
#         Age      Fare
# 0 -0.592481 -0.502445
# 1  0.638789  0.786845
# 2 -0.284663 -0.488854
# 3  0.407926  0.420730
# 4  0.407926 -0.486337

# %%
normalizer = MinMaxScaler()

df[['Age','Fare']] = normalizer.fit_transform(df[['Age','Fare']])
print("\nNormalized Age and Fare")
print(df[['Age','Fare']].head())
# Out:
# Normalized Age and Fare
#         Age      Fare
# 0  0.271174  0.014151
# 1  0.472229  0.139136
# 2  0.321438  0.015469
# 3  0.434531  0.103644
# 4  0.434531  0.015713

# %%
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)

IQR = Q3 - Q1

Lower = Q1 - 1.5 * IQR
Upper = Q3 + 1.5 * IQR

outliers = df[(df['Fare'] < Lower) | (df['Fare'] > Upper)]

print("\nNumber of Outliers in Fare:", len(outliers))
# Out:
# Number of Outliers in Fare: 116

# %%
df = df[(df['Fare'] >= Lower) & (df['Fare'] <= Upper)]

print("Dataset Shape After Removing Outliers")
print(df.shape)
# Out:
# Dataset Shape After Removing Outliers
# (775, 12)

# %%
df = df.drop(['PassengerId','Name','Ticket','Cabin'], axis=1)

print("\nFinal Dataset")
print(df.head())
# Out:
# Final Dataset
#    Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0         0       3    1  0.271174      1      0  0.014151         2
# 2         1       3    0  0.321438      0      0  0.015469         2
# 3         1       1    0  0.434531      1      0  0.103644         2
# 4         0       3    1  0.434531      0      0  0.015713         2
# 5         0       3    1  0.367921      0      0  0.016510         1

# %%
df.to_csv("Titanic_Preprocessed.csv", index=False)

print("\nPreprocessed dataset saved successfully")
# Out:
# Preprocessed dataset saved successfully
